# %% [markdown]
# # Pandas Project 2

# %% [markdown]
# ## In this project we will analyze diabetic patients by the following:
# * Age
# * Gender
# * Race
# * Readmittance

# %% [markdown]
# ### Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
# %matplotlib inline

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-74-3172e2df0836> in <module>
# ----> 1 df2.count().plot(kind='bar')
#
# NameError: name 'df2' is not defined

# %% [markdown]
# ### Data Wrangling & Cleaning

# %%
diabetic_data=pd.read_csv("diabetic_data.csv",index_col=0)

df.head()
# Out:
#    encounter_id  patient_nbr             race  gender      age weight  \
# 0       2278392      8222157        Caucasian  Female   [0-10)      ?
# 1        149190     55629189        Caucasian  Female  [10-20)      ?
# 2         64410     86047875  AfricanAmerican  Female  [20-30)      ?
# 3        500364     82442376        Caucasian    Male  [30-40)      ?
# 4         16680     42519267        Caucasian    Male  [40-50)      ?
#
#    admission_type_id  discharge_disposition_id  admission_source_id  \
# 0                  6                        25                    1
# 1                  1                         1                    7
# 2                  1                         1                    7
# 3                  1                         1                    7
# 4                  1                         1                    7
#
#    time_in_hospital  ... citoglipton insulin  glyburide-metformin  \
# ...

# %% [markdown]
# ### Renaming Variables

# %%
diabetic_data['Patient Age’]=diabetic_data[‘age'].diff().fillna(0)
diabetic_data['race’]=diabetic_data['Patient Race'].diff().fillna(0)
diabetic_data['gender’]=diabetic_data[‘Patient Gender’].diff().fillna(0)
# Out:
#   File "<ipython-input-53-b4f76aa3279d>", line 2
#     diabetic_data['race’]=diabetic_data['Patient Race'].diff().fillna(0)
#                                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# *Filtering Data

# %%
diabetic_data.groupby(['race'])['time_in_hospital'].sum()
# Out:
# race
# ?                    9750
# AfricanAmerican     86596
# Asian                2561
# Caucasian          333749
# Hispanic             8270
# Other                6436
# Name: time_in_hospital, dtype: int64

# %%
df[['age', 'gender', 'race','readmitted']]
# Out:
#             age  gender             race readmitted
# 0        [0-10)  Female        Caucasian         NO
# 1       [10-20)  Female        Caucasian        >30
# 2       [20-30)  Female  AfricanAmerican         NO
# 3       [30-40)    Male        Caucasian         NO
# 4       [40-50)    Male        Caucasian         NO
# ...         ...     ...              ...        ...
# 101761  [70-80)    Male  AfricanAmerican        >30
# 101762  [80-90)  Female  AfricanAmerican         NO
# 101763  [70-80)    Male        Caucasian         NO
# 101764  [80-90)  Female        Caucasian         NO
# 101765  [70-80)    Male        Caucasian         NO
#
# [101766 rows x 4 columns]

# %%
df[df['time_in_hospital'] == df['time_in_hospital'].max()]
# Out:
#         encounter_id  patient_nbr             race  gender      age weight  \
# 73            927786     60679647        Caucasian  Female  [70-80)      ?
# 114          1810752      6915888        Caucasian    Male  [70-80)      ?
# 151          2422806      3377124        Caucasian    Male  [40-50)      ?
# 248          2896332      3782196        Caucasian  Female  [80-90)      ?
# 280          3043728       541134        Caucasian  Female  [70-80)      ?
# ...              ...          ...              ...     ...      ...    ...
# 101324     437901938     53082900  AfricanAmerican    Male  [60-70)      ?
# 101458     439620104    185422307        Caucasian    Male  [40-50)      ?
# 101631     442012304     42673770  AfricanAmerican    Male  [40-50)      ?
# 101748     443811536    189481478        Caucasian  Female  [40-50)      ?
# 101755     443842022    188574944            Other  Female  [40-50)      ?
#
# ...

# %%
age= df.groupby(['age'])['gender']

# %%
gender= df.groupby(['gender'])

# %%
race= df.groupby(['race'])

# %% [raw]
# time_in_hosptial = df.groupby(['time_in_hospital'])['patient_nbr']

# %%
gender.count()
# Out:
#                  encounter_id  patient_nbr   race    age  weight  \
# gender
# Female                  54708        54708  54708  54708   54708
# Male                    47055        47055  47055  47055   47055
# Unknown/Invalid             3            3      3      3       3
#
#                  admission_type_id  discharge_disposition_id  \
# gender
# Female                       54708                     54708
# Male                         47055                     47055
# Unknown/Invalid                  3                         3
#
#                  admission_source_id  time_in_hospital  payer_code  ...  \
# gender                                                              ...
# Female                         54708             54708       54708  ...
# Male                           47055             47055       47055  ...
# Unknown/Invalid                    3                 3           3  ...
#
#                  citoglipton  insulin  glyburide-metformin  \
# gender
# ...

# %% [markdown]
# ## GroupBy()

# %%
df.groupby(["race"]) ['age'].count()
# Out:
# race
# ?                   2273
# AfricanAmerican    19210
# Asian                641
# Caucasian          76099
# Hispanic            2037
# Other               1506
# Name: age, dtype: int64

# %%
df.groupby(["gender"]) ["readmitted"].count()
# Out:
# gender
# Female             54708
# Male               47055
# Unknown/Invalid        3
# Name: readmitted, dtype: int64

# %% [raw]
# df.groupby(['race']).count

# %% [raw]
# df.groupby(['time_in_hospital']).count

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-90-4950efe0b7b9> in <module>
# ----> 1 time_in_hospital.count()
#
# NameError: name 'time_in_hospital' is not defined

# %% [markdown]
# #### Females have the highest rate of being readmitted

# %%
df.age
# Out:
# 0          [0-10)
# 1         [10-20)
# 2         [20-30)
# 3         [30-40)
# 4         [40-50)
#            ...
# 101761    [70-80)
# 101762    [80-90)
# 101763    [70-80)
# 101764    [80-90)
# 101765    [70-80)
# Name: age, Length: 101766, dtype: object

# %%
age.count()
# Out:
# age
# [0-10)        161
# [10-20)       691
# [20-30)      1657
# [30-40)      3775
# [40-50)      9685
# [50-60)     17256
# [60-70)     22483
# [70-80)     26068
# [80-90)     17197
# [90-100)     2793
# Name: gender, dtype: int64

# %%
df.gender
# Out:
# 0         Female
# 1         Female
# 2         Female
# 3           Male
# 4           Male
#            ...
# 101761      Male
# 101762    Female
# 101763      Male
# 101764    Female
# 101765      Male
# Name: gender, Length: 101766, dtype: object

# %%
gender.count()
# Out:
#                  encounter_id  patient_nbr   race    age  weight  \
# gender
# Female                  54708        54708  54708  54708   54708
# Male                    47055        47055  47055  47055   47055
# Unknown/Invalid             3            3      3      3       3
#
#                  admission_type_id  discharge_disposition_id  \
# gender
# Female                       54708                     54708
# Male                         47055                     47055
# Unknown/Invalid                  3                         3
#
#                  admission_source_id  time_in_hospital  payer_code  ...  \
# gender                                                              ...
# Female                         54708             54708       54708  ...
# Male                           47055             47055       47055  ...
# Unknown/Invalid                    3                 3           3  ...
#
#                  citoglipton  insulin  glyburide-metformin  \
# gender
# ...

# %% [markdown]
# #### More females were diagnosed with Diabetes than men

# %%
df.race
# Out:
# encounter_id
# 2278392            Caucasian
# 149190             Caucasian
# 64410        AfricanAmerican
# 500364             Caucasian
# 16680              Caucasian
#                   ...
# 443847548    AfricanAmerican
# 443847782    AfricanAmerican
# 443854148          Caucasian
# 443857166          Caucasian
# 443867222          Caucasian
# Name: race, Length: 101766, dtype: object

# %%
race.count()
# Out:
#                  encounter_id  patient_nbr  gender    age  weight  \
# race
# ?                        2273         2273    2273   2273    2273
# AfricanAmerican         19210        19210   19210  19210   19210
# Asian                     641          641     641    641     641
# Caucasian               76099        76099   76099  76099   76099
# Hispanic                 2037         2037    2037   2037    2037
# Other                    1506         1506    1506   1506    1506
#
#                  admission_type_id  discharge_disposition_id  \
# race
# ?                             2273                      2273
# AfricanAmerican              19210                     19210
# Asian                          641                       641
# Caucasian                    76099                     76099
# Hispanic                      2037                      2037
# Other                         1506                      1506
#
# ...

# %% [markdown]
# #### Caucasians have the highest rate of diabetes and Asians the lowest according to this chart

# %%
df.shape
# Out:
# (101766, 49)

# %%
df['diag_1']
# Out:
# encounter_id
# 2278392      250.83
# 149190          276
# 64410           648
# 500364            8
# 16680           197
#               ...
# 443847548    250.13
# 443847782       560
# 443854148        38
# 443857166       996
# 443867222       530
# Name: diag_1, Length: 101766, dtype: object

# %% [markdown]
# ## Visualization

# %%
corr =df.corr()
corr
# Out:
#                           encounter_id  patient_nbr  admission_type_id  \
# encounter_id                  1.000000     0.512028          -0.158961
# patient_nbr                   0.512028     1.000000          -0.011128
# admission_type_id            -0.158961    -0.011128           1.000000
# discharge_disposition_id     -0.132876    -0.136814           0.083483
# admission_source_id          -0.112402    -0.032568           0.106654
# time_in_hospital             -0.062221    -0.024092          -0.012500
# num_lab_procedures           -0.026062     0.015946          -0.143713
# num_procedures               -0.014225    -0.015570           0.129888
# num_medications               0.076113     0.020665           0.079535
# number_outpatient             0.103756     0.103379           0.026511
# number_emergency              0.082803     0.062352          -0.019116
# number_inpatient              0.030962     0.012480          -0.038161
# ...

# %%
df.groupby(['age'])['gender'].count().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='age'>

# %%
df.plot(kind='scatter', x='age', y='number_diagnoses')
# Out:
# <AxesSubplot:xlabel='age', ylabel='number_diagnoses'>

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'encounter_id'}>,
#         <AxesSubplot:title={'center':'patient_nbr'}>,
#         <AxesSubplot:title={'center':'admission_type_id'}>,
#         <AxesSubplot:title={'center':'discharge_disposition_id'}>],
#        [<AxesSubplot:title={'center':'admission_source_id'}>,
#         <AxesSubplot:title={'center':'time_in_hospital'}>,
#         <AxesSubplot:title={'center':'num_lab_procedures'}>,
#         <AxesSubplot:title={'center':'num_procedures'}>],
#        [<AxesSubplot:title={'center':'num_medications'}>,
#         <AxesSubplot:title={'center':'number_outpatient'}>,
#         <AxesSubplot:title={'center':'number_emergency'}>,
#         <AxesSubplot:title={'center':'number_inpatient'}>],
#        [<AxesSubplot:title={'center':'number_diagnoses'}>,
#         <AxesSubplot:>, <AxesSubplot:>, <AxesSubplot:>]], dtype=object)

# %%
df.count()
df.describe()
df.head()
df.tail()
# Out:
#               patient_nbr             race  gender      age weight  \
# encounter_id
# 443847548       100162476  AfricanAmerican    Male  [70-80)      ?
# 443847782        74694222  AfricanAmerican  Female  [80-90)      ?
# 443854148        41088789        Caucasian    Male  [70-80)      ?
# 443857166        31693671        Caucasian  Female  [80-90)      ?
# 443867222       175429310        Caucasian    Male  [70-80)      ?
#
#               admission_type_id  discharge_disposition_id  \
# encounter_id
# 443847548                     1                         3
# 443847782                     1                         4
# 443854148                     1                         1
# 443857166                     2                         3
# 443867222                     1                         1
#
#               admission_source_id  time_in_hospital payer_code  ...  \
# encounter_id                                                    ...
# ...

# %%
df.dtypes
# Out:
# encounter_id                 int64
# patient_nbr                  int64
# race                        object
# gender                      object
# age                         object
# weight                      object
# admission_type_id            int64
# discharge_disposition_id     int64
# admission_source_id          int64
# time_in_hospital             int64
# payer_code                  object
# medical_specialty           object
# num_lab_procedures           int64
# num_procedures               int64
# num_medications              int64
# number_outpatient            int64
# number_emergency             int64
# number_inpatient             int64
# diag_1                      object
# diag_2                      object
# diag_3                      object
# number_diagnoses             int64
# max_glu_serum               object
# A1Cresult                   object
# metformin                   object
# repaglinide                 object
# nateglinide                 object
# ...

# %%
# Out:
#   File "<ipython-input-32-47a3b5a38dc3>", line 1
#     df.isnull.().any()
#               ^
# SyntaxError: invalid syntax

# %%
diabetic_data = df ['race']
